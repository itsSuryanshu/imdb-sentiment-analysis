# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip3 install numpy pandas datasets

# %%
from datasets import load_dataset
import numpy as np, pandas as pd

# get imdb dataset
imdb_data = load_dataset('imdb')

# %%
train_df = pd.DataFrame(imdb_data['train'])
test_df = pd.DataFrame(imdb_data['test'])

# %%
train_df.head()
# Out:
#                                                 text  label
# 0  I rented I AM CURIOUS-YELLOW from my video sto...      0
# 1  "I Am Curious: Yellow" is a risible and preten...      0
# 2  If only to avoid making this type of film in t...      0
# 3  This film was probably inspired by Godard's Ma...      0
# 4  Oh, brother...after hearing about this ridicul...      0

# %%
train_df.tail()
# Out:
#                                                     text  label
# 24995  A hit at the time but now better categorised a...      1
# 24996  I love this movie like no other. Another time ...      1
# 24997  This film and it's sequel Barry Mckenzie holds...      1
# 24998  'The Adventures Of Barry McKenzie' started lif...      1
# 24999  The story centers around Barry McKenzie who mu...      1

# %%
train_df.shape
# Out:
# (25000, 2)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    25000 non-null  object
#  1   label   25000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 390.8+ KB

# %%
senza_obj_df = train_df.copy()
senza_obj_df.text = senza_obj_df.text.astype('string')
senza_obj_df['text'] = senza_obj_df['text'].str.replace('<br />', '')
senza_obj_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    25000 non-null  string
#  1   label   25000 non-null  int64
# dtypes: int64(1), string(1)
# memory usage: 390.8 KB

# %%
senza_obj_df.describe()
# Out:
#              label
# count  25000.00000
# mean       0.50000
# std        0.50001
# min        0.00000
# 25%        0.00000
# 50%        0.50000
# 75%        1.00000
# max        1.00000

# %% [markdown]
# ### Check if there's any null values in both columns

# %%
senza_obj_df.isnull().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %% [markdown]
# ### Check data distribution

# %%
senza_obj_df.label.value_counts(normalize=True)
# Out:
# label
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64

# %% [markdown]
# ### Analyse word count in data

# %%
strings = pd.Series([len(x.split()) for x in senza_obj_df.text])
strings.describe()
# Out:
# count    25000.000000
# mean       229.709120
# std        170.661085
# min         10.000000
# 25%        125.000000
# 50%        172.000000
# 75%        279.000000
# max       2450.000000
# dtype: float64

# %% [markdown]
# ### Find number of unique words for vocabulary

# %%
words = []
for x in senza_obj_df.text:
  words.extend(x.split())
all_words = pd.Series(words)
all_words.describe()
# Out:
# count     5742728
# unique     294381
# top           the
# freq       287038
# dtype: object
