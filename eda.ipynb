# %% [markdown]
# <a href="https://colab.research.google.com/github/itsSuryanshu/imdb-sentiment-analysis/blob/main/eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
# !pip3 install numpy pandas datasets

# %%
from datasets import load_dataset
import numpy, pandas

# get imdb dataset
imdb_data = load_dataset('imdb')

# %%
train_df = pandas.DataFrame(imdb_data['train'])
test_df = pandas.DataFrame(imdb_data['test'])

# %%
train_df.head()

# %%
train_df.tail()

# %%
train_df.shape

# %%
train_df.info()

# %%
senza_obj_df = train_df.copy()
senza_obj_df.text = senza_obj_df.text.astype('string')
senza_obj_df.info()

# %%
senza_obj_df.describe()

# %%
senza_obj_df.isnull().sum()

# %%
senza_obj_df.label.value_counts(normalize=True)
